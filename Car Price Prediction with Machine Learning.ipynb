# %%
import pandas as pd
import numpy as np
import datetime
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\siddhesh limje\Downloads\archive (17)\car data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
df['Owner'].value_counts()
# Out:
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %%
df['Transmission'].value_counts()
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %%
df['Selling_type'].value_counts()
# Out:
# Selling_type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
df['Year'].value_counts()
# Out:
# Year
# 2015    61
# 2016    50
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    19
# 2010    15
# 2008     7
# 2009     6
# 2005     4
# 2006     4
# 2007     2
# 2003     2
# 2018     1
# 2004     1
# Name: count, dtype: int64

# %%
df = df.rename(columns = {'Year' : 'Manufacturing_year'})

# %%
df
# Out:
#     Car_Name  Manufacturing_year  Selling_Price  Present_Price  Driven_kms  \
# 0       ritz                2014           3.35           5.59       27000
# 1        sx4                2013           4.75           9.54       43000
# 2       ciaz                2017           7.25           9.85        6900
# 3    wagon r                2011           2.85           4.15        5200
# 4      swift                2014           4.60           6.87       42450
# ..       ...                 ...            ...            ...         ...
# 296     city                2016           9.50          11.60       33988
# 297     brio                2015           4.00           5.90       60000
# 298     city                2009           3.35          11.00       87934
# 299     city                2017          11.50          12.50        9000
# 300     brio                2016           5.30           5.90        5464
#
#     Fuel_Type Selling_type Transmission  Owner
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Car_Name            301 non-null    object
#  1   Manufacturing_year  301 non-null    int64
#  2   Selling_Price       301 non-null    float64
#  3   Present_Price       301 non-null    float64
#  4   Driven_kms          301 non-null    int64
#  5   Fuel_Type           301 non-null    object
#  6   Selling_type        301 non-null    object
#  7   Transmission        301 non-null    object
#  8   Owner               301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df['Manufacturing_year'] = df['Manufacturing_year'].astype(int)

# %%
curr_year = datetime.datetime.now().year
df['Age_of_car'] = curr_year - df['Manufacturing_year']

# %%
df
# Out:
#     Car_Name  Manufacturing_year  Selling_Price  Present_Price  Driven_kms  \
# 0       ritz                2014           3.35           5.59       27000
# 1        sx4                2013           4.75           9.54       43000
# 2       ciaz                2017           7.25           9.85        6900
# 3    wagon r                2011           2.85           4.15        5200
# 4      swift                2014           4.60           6.87       42450
# ..       ...                 ...            ...            ...         ...
# 296     city                2016           9.50          11.60       33988
# 297     brio                2015           4.00           5.90       60000
# 298     city                2009           3.35          11.00       87934
# 299     city                2017          11.50          12.50        9000
# 300     brio                2016           5.30           5.90        5464
#
#     Fuel_Type Selling_type Transmission  Owner  Age_of_car
# ...

# %%
df.isnull().sum()
# Out:
# Car_Name              0
# Manufacturing_year    0
# Selling_Price         0
# Present_Price         0
# Driven_kms            0
# Fuel_Type             0
# Selling_type          0
# Transmission          0
# Owner                 0
# Age_of_car            0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Car_Name            299 non-null    object
#  1   Manufacturing_year  299 non-null    int64
#  2   Selling_Price       299 non-null    float64
#  3   Present_Price       299 non-null    float64
#  4   Driven_kms          299 non-null    int64
#  5   Fuel_Type           299 non-null    object
#  6   Selling_type        299 non-null    object
#  7   Transmission        299 non-null    object
#  8   Owner               299 non-null    int64
#  9   Age_of_car          299 non-null    int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 25.7+ KB

# %%
df.drop('Car_Name' , axis = 1 , inplace = True)
# Out:
# C:\Users\siddhesh limje\AppData\Local\Temp\ipykernel_19056\1188371805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Car_Name' , axis = 1 , inplace = True)

# %%
df
# Out:
#      Manufacturing_year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0                  2014           3.35           5.59       27000    Petrol
# 1                  2013           4.75           9.54       43000    Diesel
# 2                  2017           7.25           9.85        6900    Petrol
# 3                  2011           2.85           4.15        5200    Petrol
# 4                  2014           4.60           6.87       42450    Diesel
# ..                  ...            ...            ...         ...       ...
# 296                2016           9.50          11.60       33988    Diesel
# 297                2015           4.00           5.90       60000    Petrol
# 298                2009           3.35          11.00       87934    Petrol
# 299                2017          11.50          12.50        9000    Diesel
# 300                2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner  Age_of_car
# ...

# %%
Q1 = df['Selling_Price'].quantile(0.25)
Q3 = df['Selling_Price'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound, upper_bound)
# Out:
# -6.875 13.725000000000001

# %%
df[df['Selling_Price'] > upper_bound]
# Out:
#     Manufacturing_year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 50                2012          14.90          30.61      104707    Diesel
# 51                2015          23.00          30.61       40000    Diesel
# 52                2017          18.00          19.77       15000    Diesel
# 53                2013          16.00          30.61      135000    Diesel
# 59                2014          19.99          35.96       41000    Diesel
# 62                2014          18.75          35.96       78000    Diesel
# 63                2015          23.50          35.96       47000    Diesel
# 64                2017          33.00          36.23        6000    Diesel
# 66                2017          19.75          23.15       11000    Petrol
# 69                2016          14.25          20.91       12000    Petrol
# 79                2012          14.50          30.61       89000    Diesel
# ...

# %%
df['Selling_Price'].skew()
# Out:
# np.float64(2.536521826497541)

# %%
import seaborn as sns
sns.histplot(df['Selling_Price'], kde=True)
# Out:
# <Axes: xlabel='Selling_Price', ylabel='Count'>

# %%
import numpy as np
df['Selling_Price'] = np.log1p(df['Selling_Price'])
# Out:
# C:\Users\siddhesh limje\AppData\Local\Temp\ipykernel_19056\1868892726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Selling_Price'] = np.log1p(df['Selling_Price'])

# %%
df = pd.get_dummies(df , drop_first = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Manufacturing_year       299 non-null    int64
#  1   Selling_Price            299 non-null    float64
#  2   Present_Price            299 non-null    float64
#  3   Driven_kms               299 non-null    int64
#  4   Owner                    299 non-null    int64
#  5   Age_of_car               299 non-null    int64
#  6   Fuel_Type_Diesel         299 non-null    bool
#  7   Fuel_Type_Petrol         299 non-null    bool
#  8   Selling_type_Individual  299 non-null    bool
#  9   Transmission_Manual      299 non-null    bool
# dtypes: bool(4), float64(2), int64(4)
# memory usage: 17.5 KB

# %%
df['Depreciation'] = round(df['Present_Price'] - df['Selling_Price'] ,2)

# %%
df
# Out:
#      Manufacturing_year  Selling_Price  Present_Price  Driven_kms  Owner  \
# 0                  2014       1.470176           5.59       27000      0
# 1                  2013       1.749200           9.54       43000      0
# 2                  2017       2.110213           9.85        6900      0
# 3                  2011       1.348073           4.15        5200      0
# 4                  2014       1.722767           6.87       42450      0
# ..                  ...            ...            ...         ...    ...
# 296                2016       2.351375          11.60       33988      0
# 297                2015       1.609438           5.90       60000      0
# 298                2009       1.470176          11.00       87934      0
# 299                2017       2.525729          12.50        9000      0
# 300                2016       1.840550           5.90        5464      0
#
#      Age_of_car  Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df
# Out:
#      Manufacturing_year  Selling_Price  Present_Price  Driven_kms  Owner  \
# 0                  2014       1.470176           5.59       27000      0
# 1                  2013       1.749200           9.54       43000      0
# 2                  2017       2.110213           9.85        6900      0
# 3                  2011       1.348073           4.15        5200      0
# 4                  2014       1.722767           6.87       42450      0
# ..                  ...            ...            ...         ...    ...
# 296                2016       2.351375          11.60       33988      0
# 297                2015       1.609438           5.90       60000      0
# 298                2009       1.470176          11.00       87934      0
# 299                2017       2.525729          12.50        9000      0
# 300                2016       1.840550           5.90        5464      0
#
#      Age_of_car  Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual  \
# ...

# %%
x = df.drop("Selling_Price" , axis = 1)
y = df['Selling_Price']

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2 , random_state = 42)

# %% [markdown]
# ## 1.Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score
model = LinearRegression()
model.fit(x_train , y_train)
pred = model.predict(x_test)
pred
mse = mean_squared_error(y_test , pred)
r2_score = r2_score(y_test , pred)
print(mse)
print(r2_score)
# Out:
# 1.081327073191348e-05
# 0.999983443357026

# %% [markdown]
# ## 2.Random Forest

# %%
from sklearn.metrics import mean_squared_error , r2_score
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train , y_train)
pred1 = rf.predict(x_test)
pred1
mse = mean_squared_error(y_test , pred1)
r2_score = r2_score(y_test , pred1)
print(mse)
print(r2_score)
# Out:
# 0.09228656572278499
# 0.858696248540705
